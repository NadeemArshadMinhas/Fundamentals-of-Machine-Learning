# %%
import seaborn as sns # importing seaborn package for ploting
import pandas as pd # importing pandas for abbreviation in commands
import matplotlib.pyplot as plt # importing matplotlip for ploting graphs

# %%
# importing 2 datasets as in csv format
steps = pd.read_csv("steps data.csv", delimiter =";")
survey = pd.read_csv("survey data.csv")
# visualizing both data sets for data analysis
steps.head(10)
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN        NaN        NaN
# 1   2        NaN        NaN        NaN        NaN        NaN      641.0
# 2   3        NaN        NaN        NaN        NaN        NaN        NaN
# 3   4        NaN        NaN       25.0     4067.0     7192.0      154.0
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
# 5   6        NaN        NaN        NaN        NaN        NaN        NaN
# 6   7        NaN        NaN        NaN        NaN        NaN        NaN
# 7   8        NaN        NaN        NaN        NaN        NaN        NaN
# 8   9        NaN        NaN        NaN        NaN        NaN        NaN
# 9  10        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  \
# 0        NaN        NaN        NaN  ...       NaN       NaN       NaN
# ...

# %%
survey.head(10)
# Out:
#    id         city  gender    age  hh_size        hh_type  \
# 0   1  Montpellier    male  25-34        2         couple
# 1   2  Montpellier  female  25-34        2         couple
# 2   3         Lyon  female  25-34        2         couple
# 3   4         Lyon    male  25-34        3  single parent
# 4   5     Bordeaux    male  25-34        2         couple
# 5   6         Lyon    male  45-54        1         single
# 6   7     Bordeaux  female  25-34        1         single
# 7   8         Lyon  female  35-44        3  single parent
# 8   9     Bordeaux  female  25-34        3         family
# 9  10         Lyon  female  25-34        3         family
#
#              education  height  weight  waist
# 0  master or doctorate   183.0    62.0   78.0
# 1          high school   163.0    60.0   75.0
# 2  master or doctorate   172.0    65.0   60.0
# 3             bachelor   182.0    85.0   95.0
# 4  master or doctorate   177.0    70.0   81.0
# ...

# %%
#combining the 2 datasets as whole in dataframe
df = pd.merge(steps, survey, on ="id")
df.head(10)
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN        NaN        NaN
# 1   2        NaN        NaN        NaN        NaN        NaN      641.0
# 2   3        NaN        NaN        NaN        NaN        NaN        NaN
# 3   4        NaN        NaN       25.0     4067.0     7192.0      154.0
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
# 5   6        NaN        NaN        NaN        NaN        NaN        NaN
# 6   7        NaN        NaN        NaN        NaN        NaN        NaN
# 7   8        NaN        NaN        NaN        NaN        NaN        NaN
# 8   9        NaN        NaN        NaN        NaN        NaN        NaN
# 9  10        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014         city  gender  \
# 0        NaN        NaN        NaN  ...        NaN  Montpellier    male
# ...

# %%
# Getting information of variables in dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 928
# Columns: 338 entries, id to waist
# dtypes: float64(331), int64(2), object(5)
# memory usage: 2.4+ MB

# %%
df["weight"].value_counts()
# Out:
# 65.0     41
# 72.0     39
# 60.0     32
# 73.0     32
# 64.0     29
#          ..
# 106.0     1
# 117.0     1
# 102.0     1
# 37.0      1
# 155.0     1
# Name: weight, Length: 78, dtype: int64

# %%
# ploting a plot for the weight among the ids
sns.distplot(df["weight"].dropna(), kde=False)
plt.title("weight of ids")
plt.xlabel("weight(kg)")
plt.show()

# %%
# Weight statistics in mean and median
# Labeling the plot
df['weight'].name = 'weight' 
height = df['weight'].dropna() #Selecting colum size .
sns.distplot(height, kde=False) 

mean_size = df['weight'].mean()
median_size = df['weight'].median()

print(f'The median weight is: {median_size} kg')
print(f'The mean weight is: {mean_size} kg')

sns.distplot(height, kde=False)
plt.title('weight of FitBit users')
plt.axvline(median_size, 0, 100, color='green', label='median') 
plt.axvline(mean_size, 0, 100, color='red', label='mean') 
plt.legend() # adding a legend.
plt.show()
# Out:
# The median weight is: 71.0 kg
# The mean weight is: 72.0453074433657 kg

# %%
# boxplot for weight distribution
sns.boxplot(df["weight"])
plt.title('weight of ids')
plt.xlabel('weight in kg')
plt.show()

# %%
# density plot of weight
sns.distplot(height, rug=True)
plt.title('weight distribution')
plt.xlabel('weight in kg')
plt.ylabel('Amount of users')
plt.show()

# %%
# Overall statistics for weight variable 

print('median: ' + str(float(df[['weight']].median())))
print('mode: ' + str(df[['weight']].mode()['weight'][0]))
print('mean: ' + str(float(df[['weight']].mean())))
print('standard deviation: ' + str(float(df[['weight']].std())))
print('variance: ' + str(float(df[['weight']].var())))
# Out:
# median: 71.0
# mode: 65.0
# mean: 72.0453074433657
# standard deviation: 15.097312030554507
# variance: 227.92883054792583

# %%
## The weight variable is normaly distribute on the scale of 72.o with standard deviation of 15.1
## The distribution is slightly right skewed
